# %%
# %%writefile config.ipynb
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Configuration File\n",
    "# All hyperparameters and paths in one place"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# MODEL CONFIGURATION\n",
    "MODEL_CONFIG = {\n",
    "    \"base_model\": \"codellama/CodeLlama-7b-Instruct-hf\",\n",
    "    \"output_dir\": \"./codellama-coding-chat\",\n",
    "    \"checkpoint_dir\": \"./codellama-coding-chat\",\n",
    "    \"final_model_dir\": \"./codellama-coding-chat-final\",\n",
    "    \"merged_model_dir\": \"./production-model-merged\",\n",
    "    \"hf_repo_name\": \"your-username/codellama-coding-chat\",  # Change this!\n",
    "}\n",
    "\n",
    "# TRAINING CONFIGURATION\n",
    "TRAINING_CONFIG = {\n",
    "    \"num_train_epochs\": 1,\n",
    "    \"per_device_train_batch_size\": 1,\n",
    "    \"gradient_accumulation_steps\": 8,\n",
    "    \"effective_batch_size\": 8,  # batch_size * gradient_accumulation\n",
    "    \n",
    "    \"learning_rate\": 2e-4,\n",
    "    \"max_grad_norm\": 0.3,\n",
    "    \"warmup_ratio\": 0.05,\n",
    "    \"lr_scheduler_type\": \"cosine\",\n",
    "    \n",
    "    \"max_seq_length\": 1024,\n",
    "    \"logging_steps\": 25,\n",
    "    \"save_strategy\": \"steps\",\n",
    "    \"save_steps\": 500,\n",
    "    \"fp16\": True,\n",
    "    \"gradient_checkpointing\": True,\n",
    "}\n",
    "\n",
    "# LORA CONFIGURATION\n",
    "LORA_CONFIG = {\n",
    "    \"r\": 32,\n",
    "    \"lora_alpha\": 64,\n",
    "    \"lora_dropout\": 0.05,\n",
    "    \"bias\": \"none\",\n",
    "    \"task_type\": \"CAUSAL_LM\",\n",
    "    \"target_modules\": [\n",
    "        \"q_proj\", \"k_proj\", \"v_proj\", \"o_proj\",\n",
    "        \"gate_proj\", \"up_proj\", \"down_proj\",\n",
    "    ],\n",
    "}\n",
    "\n",
    "# QUANTIZATION CONFIGURATION\n",
    "BNB_CONFIG = {\n",
    "    \"load_in_4bit\": True,\n",
    "    \"bnb_4bit_quant_type\": \"nf4\",\n",
    "    \"bnb_4bit_compute_dtype\": \"float16\",  # T4 uses float16, A100 can use bfloat16\n",
    "    \"bnb_4bit_use_double_quant\": True,\n",
    "}\n",
    "\n",
    "# DATASET CONFIGURATION\n",
    "DATA_CONFIG = {\n",
    "    \"code_dataset\": \"iamtarun/python_code_instructions_18k_alpaca\",\n",
    "    \"chat_dataset\": \"mlabonne/orpo-dpo-mix-40k\",\n",
    "    \"code_samples\": 15000,\n",
    "    \"chat_samples\": 6000,\n",
    "    \"code_ratio\": 0.7,\n",
    "    \"chat_ratio\": 0.3,\n",
    "    \"train_test_split\": 0.05,  # 5% for evaluation\n",
    "}\n",
    "\n",
    "# INFERENCE CONFIGURATION\n",
    "INFERENCE_CONFIG = {\n",
    "    \"max_new_tokens\": 512,\n",
    "    \"temperature\": 0.7,\n",
    "    \"top_p\": 0.9,\n",
    "    \"do_sample\": True,\n",
    "    \"repetition_penalty\": 1.1,\n}",
    "\n",
    "print(\"✅ Configuration loaded!\")\n",
    "print(f\"Base model: {MODEL_CONFIG['base_model']}\")\n",
    "print(f\"Training epochs: {TRAINING_CONFIG['num_train_epochs']}\")\n",
    "print(f\"LoRA rank: {LORA_CONFIG['r']}\")\n",
    "print(f\"Code/Chat ratio: {DATA_CONFIG['code_ratio']}/{DATA_CONFIG['chat_ratio']}\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
